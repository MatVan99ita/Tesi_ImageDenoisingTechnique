# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import random
import matplotlib.pyplot as plt
from skimage.util import random_noise
from tensorflow.keras.layers import Layer, Conv2D, Add, ReLU, Concatenate, GlobalAveragePooling2D, Multiply, Input, Lambda,  MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Model
from keras.models import load_model
from tensorflow.keras.saving import register_keras_serializable

# %%
def plot_side_by_side(x_noisy, x_original, n=10):
    """
    Visualizza n coppie di immagini affiancando l'immagine rumorosa e quella originale per immagini a colori.
    """
    plt.figure(figsize=(20, 4))
    for i in range(n):
        # Immagine rumorosa
        ax = plt.subplot(2, n, i+1)
        plt.imshow(x_noisy[i])
        plt.title("Rumorosa")
        plt.axis('off')

        # Immagine originale
        ax = plt.subplot(2, n, i+1+n)
        plt.imshow(x_original[i])
        plt.title("Originale")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
def plot_denoising_results(x_test_noisy, decoded_imgs, x_test, n=10):
    """
    Visualizza n immagini rumorose, le rispettive immagini denoised e quelle originali.
    """
    plt.figure(figsize=(20, 4))
    n = 10
    for i in range(n):
        # Immagine rumorosa
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(x_test_noisy[i])
        plt.title("Rumorosa")
        plt.axis('off')
        # Immagine denoised
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(decoded_imgs[i])
        plt.title("Denoised")
        plt.axis('off')
        # Immagine originale
        ax = plt.subplot(3, n, i + 1 + 2*n)
        plt.imshow(x_test[i])
        plt.title("Originale")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
def plot_side_by_side(x_noisy, x_original, n=10):
    """
    Visualizza n coppie di immagini affiancando l'immagine rumorosa e quella originale per immagini a colori.
    """
    plt.figure(figsize=(20, 4))
    for i in range(n):
        # Immagine rumorosa
        ax = plt.subplot(2, n, i+1)
        plt.imshow(x_noisy[i])
        plt.title("Rumorosa")
        plt.axis('off')

        # Immagine originale
        ax = plt.subplot(2, n, i+1+n)
        plt.imshow(x_original[i])
        plt.title("Originale")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
# MeanShift: sottrae (o aggiunge) la media RGB
@register_keras_serializable("MeanShift")
class MeanShift(Layer):
    def __init__(self, rgb_mean, sign=-1, **kwargs):
        """
        rgb_mean: tupla con la media dei canali R, G, B.
        sign: -1 per sottrarre la media, 1 per aggiungerla.
        """
        super(MeanShift, self).__init__(**kwargs)
        self.rgb_mean = tf.constant(rgb_mean, dtype=tf.float32)
        self.sign = sign

    def call(self, x):
        # x è atteso in formato (batch, altezza, larghezza, 3)
        # Sfruttiamo Lambda per eseguire l'operazione per ogni elemento
        # Nota: non stiamo scalando per std in questo esempio
        return x + self.sign * self.rgb_mean

# BasicBlock: Conv2D seguita da attivazione ReLU
@register_keras_serializable("BasicBlock")
class BasicBlock(Layer):
    def __init__(self, out_channels, kernel_size=3, stride=1, use_bias=False, **kwargs):
        super(BasicBlock, self).__init__(**kwargs)
        self.conv = Conv2D(out_channels, kernel_size, strides=stride,
                           padding='same', use_bias=use_bias)
        self.relu = ReLU()

    def call(self, x):
        return self.relu(self.conv(x))

# ResidualBlock: due convoluzioni con skip connection(come lavora cuda con 2 thread -> 2 filtri applicati e poi si uniscono i risultati)
@register_keras_serializable("ResidualBlock")
class ResidualBlock(Layer):
    def __init__(self, out_channels, **kwargs):
        super(ResidualBlock, self).__init__(**kwargs)
        self.conv1 = Conv2D(out_channels, 3, strides=1, padding='same')
        self.relu = ReLU()
        self.conv2 = Conv2D(out_channels, 3, strides=1, padding='same')

    def call(self, x):
        residual = self.conv1(x)
        residual = self.relu(residual)
        residual = self.conv2(residual)
        out = Add()([x, residual])
        return ReLU()(out)

# EResidualBlock: versione estesa con convoluzioni a gruppi
@register_keras_serializable("EResidualBlock")
class EResidualBlock(Layer):
    def __init__(self, out_channels, groups=1, **kwargs):
        super(EResidualBlock, self).__init__(**kwargs)
        self.conv1 = Conv2D(out_channels, 3, strides=1, padding='same', groups=groups)
        self.relu = ReLU()
        self.conv2 = Conv2D(out_channels, 3, strides=1, padding='same', groups=groups)
        self.conv3 = Conv2D(out_channels, 1, strides=1, padding='valid')

    def call(self, x):
        residual = self.conv1(x)
        residual = self.relu(residual)
        residual = self.conv2(residual)
        residual = self.relu(residual)
        residual = self.conv3(residual)
        out = Add()([x, residual])
        return ReLU()(out)

# Merge_Run_dual: due rami convoluzionali con dilatazioni diverse, poi fusione e skip connection
@register_keras_serializable("MergeRunDual")
class MergeRunDual(Layer):
    def __init__(self, out_channels, **kwargs):
        super(MergeRunDual, self).__init__(**kwargs)
        # Primo ramo
        self.conv1a = Conv2D(out_channels, 3, strides=1, padding='same')
        self.relu1a = ReLU()
        self.conv1b = Conv2D(out_channels, 3, strides=1, padding='same', dilation_rate=2)
        self.relu1b = ReLU()
        # Secondo ramo
        self.conv2a = Conv2D(out_channels, 3, strides=1, padding='same', dilation_rate=3)
        self.relu2a = ReLU()
        self.conv2b = Conv2D(out_channels, 3, strides=1, padding='same', dilation_rate=4)
        self.relu2b = ReLU()
        # Gogeta
        self.conv3 = Conv2D(out_channels, 3, strides=1, padding='same')
        self.relu3 = ReLU()

    def call(self, x):
        branch1 = self.relu1a(self.conv1a(x))
        branch1 = self.relu1b(self.conv1b(branch1))

        branch2 = self.relu2a(self.conv2a(x))
        branch2 = self.relu2b(self.conv2b(branch2))

        merged = Concatenate()([branch1, branch2])
        merged = self.relu3(self.conv3(merged))
        return Add()([merged, x])

# CALayer: Channel Attention Layer
@register_keras_serializable("CALayer")
class CALayer(Layer):
    def __init__(self, channel, reduction=16, **kwargs):
        super(CALayer, self).__init__(**kwargs)
        self.channel = channel
        self.reduction = reduction
        self.conv1 = Conv2D(channel // reduction, 1, strides=1, padding='same')
        self.relu = ReLU()
        self.conv2 = Conv2D(channel, 1, strides=1, padding='same', activation='sigmoid') #sigmoid: risultato tra 0 e 1

    def call(self, x):
        # Calcolo della media globale per canale
        y = tf.reduce_mean(x, axis=[1, 2], keepdims=True)
        y = self.relu(self.conv1(y))
        y = self.conv2(y)
        return Multiply()([x, y])

# Block: combinazione di MergeRunDual, ResidualBlock, EResidualBlock e CALayer
@register_keras_serializable("Block")
class Block(Layer):
    def __init__(self, out_channels, **kwargs):
        super(Block, self).__init__(**kwargs)
        self.merge_run_dual = MergeRunDual(out_channels)
        self.residual_block = ResidualBlock(out_channels)
        self.e_residual_block = EResidualBlock(out_channels)
        self.ca = CALayer(out_channels)

    def call(self, x):
        r1 = self.merge_run_dual(x)
        r2 = self.residual_block(r1)
        r3 = self.e_residual_block(r2)
        out = self.ca(r3)
        return out

# RIDNET: il modello final
@register_keras_serializable("RIDNET")
def RIDNET(n_feats=64, rgb_range=1.0):
    """
    n_feats: numero di feature channels usate all'interno del modello.<br>
    rgb_range: scala dei valori RGB (ad es. 1.0 se l'input è normalizzato [0,1]).
    """
    rgb_mean = (0.4488, 0.4371, 0.4040)

    input_layer = Input(shape=(None, None, 3))

    # Sottosottrai la media (MeanShift con sign=-1)
    sub_mean = MeanShift(rgb_mean, sign=-1)
    x = sub_mean(input_layer)

    # Testa: BasicBlock (conv + ReLU)
    head = Conv2D(n_feats, 3, strides=1, padding='same', activation='relu')(x)

    # Serie di blocchi
    b1 = Block(n_feats)(head)
    b2 = Block(n_feats)(b1)
    b3 = Block(n_feats)(b2)
    b4 = Block(n_feats)(b3)

    # Coda: convoluzione finale per ottenere 3 canali
    tail = Conv2D(3, 3, strides=1, padding='same')(b4)

    # Aggiungi la media (MeanShift con sign=+1)
    add_mean = MeanShift(rgb_mean, sign=1)
    res = add_mean(tail)

    # Connessione residua a livello di immagine: somma con l'input originale
    output = Add()([res, input_layer])

    model = Model(inputs=input_layer, outputs=output)
    return model

# %%
def preprocess(sample, img_size=(256, 256)):
    """
    Preprocessa una singola immagine:
      - Normalizza (0, 1)
      - Ridimensiona a img_size
    """
    image = tf.cast(sample['image'], tf.float32) / 255.0
    image = tf.image.resize(image, img_size)
    return image

def load_dataset(split='train', img_size=(256,256), batch_size=16):
    """
    Carica il dataset Oxford-IIIT Pet da tfds e applica il preprocessamento.
    Ritorna un dataset in batch.
    """
    ds_split = 'train[:80%]'
    if(split == 'validation'):
      ds_split = 'train[80%:]'
    elif(split != 'train' or split != 'validation'):
      ds_split = 'test'

    dataset = tfds.load('oxford_iiit_pet', split=ds_split, as_supervised=False)  # as_supervised=False per mantenere dict
    dataset = dataset.map(lambda sample: preprocess(sample, img_size))  # Preprocessing
    dataset = dataset.shuffle(1024).batch(batch_size).prefetch(tf.data.AUTOTUNE)  # Ottimizza il caricamento
    return dataset

# %%
# Parametri
img_size = (112, 112)
batch_size = 64
noise_factor = 0.4
epochs = 50

# Caricamento dataset
train_ds = load_dataset(split='train',       img_size=img_size, batch_size=batch_size )
valid_ds = load_dataset( split='validation', img_size=img_size, batch_size=batch_size )
test_ds  = load_dataset(split='test',        img_size=img_size, batch_size=batch_size )
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/oxford_iiit_pet/4.0.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/oxford_iiit_pet/4.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_iiit_pet/incomplete.BMEH0K_4.0.0/oxford_iiit_pet-train.tfrecord*...…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_iiit_pet/incomplete.BMEH0K_4.0.0/oxford_iiit_pet-test.tfrecord*...:…
# Dataset oxford_iiit_pet downloaded and prepared to /root/tensorflow_datasets/oxford_iiit_pet/4.0.0. Subsequent calls will reuse this data.

# %%
def add_noise(x, noise_factor=0.1):
    noise = tf.random.normal(shape=tf.shape(x), mean=0.0, stddev=1.0)
    x_noisy = x + noise_factor * noise
    return x_noisy

# %%
train_ds_noisy = train_ds.map(lambda x: (add_noise(x, noise_factor), x))
valid_ds_noisy = train_ds.map(lambda x: (add_noise(x, noise_factor), x))

test_ds_noisy = test_ds.map(lambda x: (add_noise(x, noise_factor), x))

# %%
# Prendi un batch dal dataset (ad esempio, il primo batch)
batch = next(iter(train_ds_noisy))

x_noisy_batch, x_original_batch = batch

# Converti i tensori in array NumPy
x_noisy_np = x_noisy_batch.numpy()
x_original_np = x_original_batch.numpy()

# Usa la funzione plot_side_by_side per visualizzare n immagini
plot_side_by_side(x_noisy_np, x_original_np, n=10)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.63287..2.2561698].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.510425..2.192344].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4002888..2.1802871].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4385041..2.293282].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.2949904..2.577071].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5816821..2.0814593].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.6546837..2.0496545].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.232317..2.3473127].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.379805..2.5554585].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7167035..2.3954282].

# %%
# Prendi un batch dal dataset (ad esempio, il primo batch)
batch = next(iter(valid_ds_noisy))
x_noisy_batch, x_original_batch = batch

# Converti i tensori in array NumPy
x_noisy_np = x_noisy_batch.numpy()
x_original_np = x_original_batch.numpy()

# Usa la funzione plot_side_by_side per visualizzare n immagini
plot_side_by_side(x_noisy_np, x_original_np, n=10)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.3694144..2.5944006].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.1685737..2.2994184].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.3920112..2.373896].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.1113546..2.2682638].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.419423..1.9359822].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4875462..2.381953].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.1591297..2.523601].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5399979..2.0937452].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.457519..2.3050356].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.3662345..2.4640338].

# %%
# Prendi un batch dal dataset (ad esempio, il primo batch)
batch = next(iter(valid_ds_noisy))
x_noisy_batch, x_original_batch = batch

# Converti i tensori in array NumPy
x_noisy_np_test = x_noisy_batch.numpy()
x_original_np_test = x_original_batch.numpy()

# Usa la funzione plot_side_by_side per visualizzare n immagini
plot_side_by_side(x_noisy_np_test, x_original_np_test, n=10)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.363437..2.3270109].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.239175..2.2599514].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.2507308..2.1950872].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.417438..2.1839797].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.3164899..2.254979].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4485086..2.2851567].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.3084991..2.7046788].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.3041139..2.3682842].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.2879804..2.17663].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.2443368..2.2079349].

# %%
model = RIDNET(n_feats=32, rgb_range=1.0)
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'] )
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mean_shift          │ (None, None,      │          0 │ input_layer[0][0] │
# │ (MeanShift)         │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, None,      │        896 │ mean_shift[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block (Block)       │ (None, None,      │     93,666 │ conv2d[0][0]      │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1 (Block)     │ (None, None,      │     93,666 │ block[0][0]       │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2 (Block)     │ (None, None,      │     93,666 │ block_1[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3 (Block)     │ (None, None,      │     93,666 │ block_2[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, None,      │        867 │ block_3[0][0]     │
# │                     │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mean_shift_1        │ (None, None,      │          0 │ conv2d_49[0][0]   │
# │ (MeanShift)         │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_36 (Add)        │ (None, None,      │          0 │ mean_shift_1[0][… │
# │                     │ None, 3)          │            │ input_layer[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 376,427 (1.44 MB)
#  Trainable params: 376,427 (1.44 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_ds_noisy,
              epochs=50,
              batch_size=batch_size,
              validation_data=valid_ds_noisy)
# Out:
# Epoch 1/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.4147 - loss: 0.2058 - val_accuracy: 0.4060 - val_loss: 0.1408
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4157 - loss: 0.1142 - val_accuracy: 0.4475 - val_loss: 0.0514
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4866 - loss: 0.0371 - val_accuracy: 0.5678 - val_loss: 0.0232
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.5408 - loss: 0.0201 - val_accuracy: 0.5603 - val_loss: 0.0162
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.5655 - loss: 0.0161 - val_accuracy: 0.5638 - val_loss: 0.0151
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.5835 - loss: 0.0139 - val_accuracy: 0.6078 - val_loss: 0.0128
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.6056 - loss: 0.0126 - val_accuracy: 0.6104 - val_loss: 0.0145
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.6008 - loss: 0.0123 - val_accuracy: 0.6334 - val_loss: 0.0108
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.6262 - loss: 0.0109 - val_accuracy: 0.6373 - val_loss: 0.0104
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.6350 - loss: 0.0103 - val_accuracy: 0.6284 - val_loss: 0.0101
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.6433 - loss: 0.0099 - val_accuracy: 0.6499 - val_loss: 0.0096
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.6442 - loss: 0.0099 - val_accuracy: 0.6701 - val_loss: 0.0100
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.6424 - loss: 0.0099 - val_accuracy: 0.6679 - val_loss: 0.0096
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.6527 - loss: 0.0094 - val_accuracy: 0.6369 - val_loss: 0.0092
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.6575 - loss: 0.0092 - val_accuracy: 0.6502 - val_loss: 0.0091
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.6691 - loss: 0.0090 - val_accuracy: 0.6368 - val_loss: 0.0089
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.6675 - loss: 0.0089 - val_accuracy: 0.6634 - val_loss: 0.0087
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.6583 - loss: 0.0092 - val_accuracy: 0.6832 - val_loss: 0.0096
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.6657 - loss: 0.0091 - val_accuracy: 0.6752 - val_loss: 0.0086
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.6753 - loss: 0.0085 - val_accuracy: 0.6779 - val_loss: 0.0083
# Epoch 21/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.6776 - loss: 0.0083 - val_accuracy: 0.6895 - val_loss: 0.0082
# Epoch 22/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.6795 - loss: 0.0083 - val_accuracy: 0.6665 - val_loss: 0.0083
# Epoch 23/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.6836 - loss: 0.0081 - val_accuracy: 0.6668 - val_loss: 0.0080
# Epoch 24/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.6844 - loss: 0.0080 - val_accuracy: 0.6587 - val_loss: 0.0079
# Epoch 25/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.6852 - loss: 0.0079 - val_accuracy: 0.6737 - val_loss: 0.0078
# Epoch 26/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.6856 - loss: 0.0078 - val_accuracy: 0.6687 - val_loss: 0.0081
# Epoch 27/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.6891 - loss: 0.0080 - val_accuracy: 0.7023 - val_loss: 0.0076
# Epoch 28/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.6893 - loss: 0.0077 - val_accuracy: 0.6560 - val_loss: 0.0076
# Epoch 29/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.6977 - loss: 0.0077 - val_accuracy: 0.6709 - val_loss: 0.0076
# Epoch 30/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.7017 - loss: 0.0076 - val_accuracy: 0.6943 - val_loss: 0.0073
# Epoch 31/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.6947 - loss: 0.0075 - val_accuracy: 0.7020 - val_loss: 0.0074
# Epoch 32/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.7072 - loss: 0.0073 - val_accuracy: 0.7210 - val_loss: 0.0073
# Epoch 33/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.7019 - loss: 0.0075 - val_accuracy: 0.6894 - val_loss: 0.0074
# Epoch 34/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.7054 - loss: 0.0073 - val_accuracy: 0.6954 - val_loss: 0.0071
# Epoch 35/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.7136 - loss: 0.0071 - val_accuracy: 0.7274 - val_loss: 0.0070
# Epoch 36/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.7196 - loss: 0.0070 - val_accuracy: 0.7060 - val_loss: 0.0071
# Epoch 37/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.7200 - loss: 0.0070 - val_accuracy: 0.7217 - val_loss: 0.0070
# Epoch 38/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7223 - loss: 0.0070 - val_accuracy: 0.7275 - val_loss: 0.0069
# Epoch 39/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.7196 - loss: 0.0069 - val_accuracy: 0.7350 - val_loss: 0.0069
# Epoch 40/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.7264 - loss: 0.0069 - val_accuracy: 0.7154 - val_loss: 0.0071
# Epoch 41/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7246 - loss: 0.0069 - val_accuracy: 0.7346 - val_loss: 0.0068
# Epoch 42/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.7131 - loss: 0.0069 - val_accuracy: 0.7213 - val_loss: 0.0069
# Epoch 43/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.7273 - loss: 0.0069 - val_accuracy: 0.7276 - val_loss: 0.0068
# Epoch 44/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.7230 - loss: 0.0069 - val_accuracy: 0.7193 - val_loss: 0.0068
# Epoch 45/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.7285 - loss: 0.0068 - val_accuracy: 0.7359 - val_loss: 0.0068
# Epoch 46/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.7253 - loss: 0.0067 - val_accuracy: 0.7375 - val_loss: 0.0067
# Epoch 47/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.7282 - loss: 0.0067 - val_accuracy: 0.7346 - val_loss: 0.0068
# Epoch 48/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7298 - loss: 0.0067 - val_accuracy: 0.7307 - val_loss: 0.0067
# Epoch 49/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.7248 - loss: 0.0068 - val_accuracy: 0.7017 - val_loss: 0.0067
# Epoch 50/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7237 - loss: 0.0067 - val_accuracy: 0.7003 - val_loss: 0.0069

# %%
decoded_imgs = model.predict(x_noisy_np_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step

# %%
plot_denoising_results(x_noisy_np_test, decoded_imgs, x_original_np_test, n=10)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.363437..2.3270109].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.08360666..1.0302622].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.239175..2.2599514].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.12991446..1.1656374].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.2507308..2.1950872].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.417438..2.1839797].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.59551483..0.9085864].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.3164899..2.254979].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.24163872..1.0443115].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4485086..2.2851567].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.00800547..1.0079367].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.3084991..2.7046788].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.062230468..1.1942725].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.3041139..2.3682842].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0508911..1.0402952].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.2879804..2.17663].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.14007825..1.1840792].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.2443368..2.2079349].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.036270857..0.9012486].

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(epochs)

# %%
model.save('new_RIDNET.keras')

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from skimage.metrics import peak_signal_noise_ratio as psnr
from collections import defaultdict

# %%
def calculate_psnr(img1, img2):
    """
    Calcola il PSNR tra due immagini TensorFlow (img1 e img2).
    Entrambe devono essere float32 e normalizzate (0-1) o in uint8 (0-255).
    """
    return tf.image.psnr(img1, img2, max_val=1.0 if img1.dtype.is_floating else 255.0).numpy()

# %%
def plot_psnr_vs_noise(psnr_dict):
    levels = sorted(psnr_dict.keys())
    psnr_values = [psnr_dict[level] for level in levels]

    plt.figure(figsize=(8, 5))
    plt.plot(levels, psnr_values, marker='o')
    plt.xlabel("Fattore di rumore")
    plt.ylabel("PSNR medio (dB)")
    plt.title("PSNR vs Livello di Rumore")
    plt.grid(True)
    plt.show()

# %%
def psnr_by_noise_level(noisy_images, original_images, noise_levels):
    psnr_dict = defaultdict(list)

    for noisy, original, level in zip(noisy_images, original_images, noise_levels):
        psnr = calculate_psnr(tf.convert_to_tensor(noisy), tf.convert_to_tensor(original))
        psnr_dict[level].append(psnr)

    # Calcola media per ogni livello di rumore
    avg_psnr_by_level = {level: np.mean(values) for level, values in psnr_dict.items()}

    return avg_psnr_by_level

# %%
noise_levels = np.linspace(0,1,11)

# %%
x_noisy_np_test, decoded_imgs, x_original_np_test
avg_psnr = psnr_by_noise_level(x_noisy_np_test, x_original_np_test, noise_levels)
plot_psnr_vs_noise(avg_psnr)

# %%
psnr_values = [psnr(x_noisy_np[i], decoded_imgs[i], data_range=1.0) for i in range(len(x_noisy_np))]

# %%
# Plot dei PSNR per ogni immagine
plt.figure(figsize=(10, 4))
plt.plot(psnr_values, marker='o', linestyle='-', color='green')
plt.title('PSNR per ogni immagine di test')
plt.xlabel('Indice immagine')
plt.ylabel('PSNR (dB)')
plt.grid(True)
plt.show()

# (Facoltativo) Media PSNR
print(f"Media PSNR sul test set: {np.mean(psnr_values):.2f} dB")
# Out:
# Media PSNR sul test set: 5.37 dB
